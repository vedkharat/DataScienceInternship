# %% [markdown]
# <a href="https://colab.research.google.com/github/vedkharat/DataScienceInternship/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Programmer: Ved Kharat
#College: Keystone
#Class:TE-A
#Roll No:35

# %% [markdown]
# Dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/student3.csv')
df.head()
# Out:
#    roll     name class  marks    age
# 0     1     anil    TE   56.77  22.0
# 1     2     amit    TE   59.77  21.0
# 2     3   aniket    BE   76.88  19.0
# 3     4  ajinkya    TE   69.66  20.0
# 4     5     asha    TE   63.28   NaN

# %%
df['age'].mean()
# Out:
# 20.785714285714285

# %%
df['marks '].mean()
# Out:
# 66.96714285714286

# %%
df.columns.str.strip()
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.columns=df.columns.str.strip()
df['marks'].mean()
# Out:
# 67.75307692307693

# %%
df.groupby('class').sum()
# Out:
#        roll                                           name   marks    age
# class
# BE       26                          aniketayeshaamaranmol  220.88   58.0
# TE       68  anilamitajinkyaashaamolamolsurbhiSujayshalini  500.55  168.0
# be       21                                   Amitasubhash  156.78   44.0

# %%
df.value_counts('class')
# Out:
# class
# TE    9
# BE    4
# be    2
# Name: count, dtype: int64

# %%
df['class'].str.upper().value_counts()
# Out:
# class
# TE    9
# BE    6
# Name: count, dtype: int64

# %%
df['class']=df['class'].str.upper()
df['class'].value_counts()
# Out:
# class
# TE    9
# BE    6
# Name: count, dtype: int64

# %%
df.name=df.name.str.title()
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 9      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df.describe()
# Out:
#             roll     marks         age
# count  16.000000  14.000000  14.000000
# mean    8.062500  66.967143  20.785714
# std     4.327721   9.640749   1.311404
# min     1.000000  56.750000  19.000000
# 25%     4.750000  59.440000  20.000000
# 50%     8.500000  64.395000  20.500000
# 75%    11.250000  73.005000  21.750000
# max    15.000000  88.450000  23.000000

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df.notnull()
# Out:
#     roll  name  class  marks     age
# 0   True  True   True    True   True
# 1   True  True   True    True   True
# 2   True  True   True    True   True
# 3   True  True   True    True   True
# 4   True  True   True    True  False
# 5   True  True   True   False   True
# 6   True  True   True    True   True
# 7   True  True   True    True   True
# 8   True  True   True    True   True
# 10  True  True   True    True  False
# 11  True  True   True   False   True
# 12  True  True   True    True   True
# 13  True  True   True    True   True
# 14  True  True  False    True   True
# 15  True  True   True    True   True

# %%
df.count()
# Out:
# roll      15
# name      15
# class     14
# marks     13
# age       13
# dtype: int64

# %%
False + False
# Out:
# 0

# %%
False + True
# Out:
# 1

# %%
True + True
# Out:
# 2

# %%
df.isna().sum()
# Out:
# roll      0
# name      0
# class     1
# marks     2
# age       2
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     1
# 6     0
# 7     0
# 8     0
# 10    1
# 11    1
# 12    0
# 13    0
# 14    1
# 15    0
# dtype: int64

# %% [markdown]
# Drops all the missing values

# %%
df.dropna()
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 15    15  Shalini    TE   63.45  20.0

# %% [markdown]
# Mau

# %%
df['marks']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df['age'].fillna('20')
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4       20
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 10      20
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: object

# %%
df['marks'].fillna('50')
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5        50
# 6     65.34
# 7     68.33
# 8     56.75
# 10    78.66
# 11       50
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: object

# %% [markdown]
# Mean/Meadian/Mode of remaining data

# %%
df['marks'].fillna(df['marks'].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     67.753077
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 10    78.660000
# 11    67.753077
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks, dtype: float64

# %%
df['age'].fillna(df['age'].median())
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     21.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 10    21.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df['class'].mode()
# Out:
# 0    TE
# Name: class, dtype: object

# %%
df['class'].mode()[0]
# Out:
# 'TE'

# %%
df['class'].fillna(df['class'].mode()[0])
# Out:
# 0     TE
# 1     TE
# 2     BE
# 3     TE
# 4     TE
# 5     BE
# 6     BE
# 7     be
# 8     TE
# 10    BE
# 11    TE
# 12    TE
# 13    be
# 14    TE
# 15    TE
# Name: class, dtype: object

# %% [markdown]
# 4. ffill()=uses the forward value of that element

# %%
df.ffill()
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  63.28  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  20.0
# 11    11   Surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    be  88.45  21.0
# 14    14   Sachin    be  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.bfill(inplace=True)
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  65.34  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  23.0
# 11    11   Surbhi    TE  74.12  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    be  88.45  21.0
# 14    14   Sachin    TE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %% [markdown]
# Outlier Detection

# %%
import numpy as np

# %%
np.random.randint(1,100)
# Out:
# 82

# %%
sal=[]
for i in range(100):
  num=np.random.randint(20000,35000)
  sal.append(num)

# %%
df=pd.DataFrame({'salary':sal})
df.shape
# Out:
# (100, 1)

# %%
df.iloc[33,:]=45000

# %%
df.iloc[64,:]=35000

# %%
df.head(65)
# Out:
#     salary
# 0    20305
# 1    33715
# 2    31870
# 3    31052
# 4    33551
# ..     ...
# 60   31162
# 61   25297
# 62   30726
# 63   25133
# 64   35000
#
# [65 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bf263987340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bf2639878b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bf2639870a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bf263987df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bf2639b40d0>],
#  'means': []}

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
ndf=df[df['salary']<40000]
ndf.shape
# Out:
# (99, 1)

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.shape
# Out:
# (100, 1)

# %%
df.describe()
# Out:
#              salary
# count    100.000000
# mean   27957.490000
# std     4446.249268
# min    20209.000000
# 25%    24456.750000
# 50%    28153.000000
# 75%    31208.000000
# max    45000.000000

# %%
Q1=np.percentile(df['salary'],25)
Q3=np.percentile(df['salary'],75)
Q1,Q3
# Out:
# (24456.75, 31208.0)

# %%
IQR=Q3-Q1
upper_fence=Q3+IQR*1.5
lower_fence=Q1-IQR*1.5
upper_fence,lower_fence
# Out:
# (41334.875, 14329.875)

# %%
ndf=df[(df['salary']>lower_fence)&(df['salary']<upper_fence)]
ndf.shape
# Out:
# (99, 1)
