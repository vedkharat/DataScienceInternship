# %% [markdown]
# <a href="https://colab.research.google.com/github/vedkharat/DataScienceInternship/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Programmer: Ved Kharat
#College: Keystone
#Class:TE-A
#Roll No:35

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Array

# %%
num = np.array([1,2,3,4,5,6,7,])

# %%
num
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
num.dtype
# Out:
# dtype('int64')

# %%
num[5]
# Out:
# 6

# %% [markdown]
# series

# %%
s=pd.Series([22,33,44,55,66,77,])
s
# Out:
# 0    22
# 1    33
# 2    44
# 3    55
# 4    66
# 5    77
# dtype: int64

# %%
s.size
# Out:
# 6

# %%
s.shape
# Out:
# (6,)

# %% [markdown]
# DataFrame

# %%
r=pd.Series([11,22,33,44,55])
n=pd.Series(['ved','plant','om','adnan','dama'])
m=pd.Series([65.98,75.65,77.66,73.22,77.77])

# %%
df =pd.DataFrame({
    'Roll':r,
    'Name':n,
    'Marks':m
})

# %%
df
# Out:
#    Roll   Name  Marks
# 0    11    ved  65.98
# 1    22  plant  75.65
# 2    33     om  77.66
# 3    44  adnan  73.22
# 4    55   dama  77.77

# %%
df.shape
df.size
df.dtypes
# Out:
# Roll       int64
# Name      object
# Marks    float64
# dtype: object

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# Import the file

# %%
df=pd.read_csv('/content/student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1=pd.read_csv('/content/student3.tsv' , sep="\t")
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df2=pd.read_csv('https://gist.githubusercontent.com/justimchung/9b98c69b30600a46daa6d2e827c31b56/raw/4b1f08ba9b00a2fcd3f7ced9cf9e59062f489c3a/student.csv')

# %%
df2
# Out:
#   Unnamed: 0    Name  height  weight  sex       bdate       city major
# 0   s1234567   Peter   175.0   70.45    1   1980/4/30     Tainan  CSIE
# 1   e1234567    Mary   163.0   55.00    2  1981/12/21     Taipei    EE
# 2   f1357689    John   180.4   80.30    1   1980/5/30     Tainan  Stat
# 3   e1374659   Keven   182.5   77.60    1  1980/11/19     Taipei    EE
# 4   s7758347    JoJo   170.3   50.30    2   1980/1/27     Taipei  CSIE
# 5   s1334987   Emily   168.5   53.60    2  1982/10/13  Kaohsiung  CSIE
# 6   e1384726  Ubuntu   177.0   68.30    1    1981/7/6  Kaohsiung    EE

# %%
df2.shape
# Out:
# (7, 8)

# %%
df2.size
# Out:
# 56

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'height', 'weight', 'sex', 'bdate', 'city',
#        'major'],
#       dtype='object')

# %%
df2.ndim
# Out:
# 2

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# functions and methods

# %%
df2.head(4)
# Out:
#   Unnamed: 0   Name  height  weight  sex       bdate    city major
# 0   s1234567  Peter   175.0   70.45    1   1980/4/30  Tainan  CSIE
# 1   e1234567   Mary   163.0   55.00    2  1981/12/21  Taipei    EE
# 2   f1357689   John   180.4   80.30    1   1980/5/30  Tainan  Stat
# 3   e1374659  Keven   182.5   77.60    1  1980/11/19  Taipei    EE

# %%
df2.tail(4)
# Out:
#   Unnamed: 0    Name  height  weight  sex       bdate       city major
# 3   e1374659   Keven   182.5    77.6    1  1980/11/19     Taipei    EE
# 4   s7758347    JoJo   170.3    50.3    2   1980/1/27     Taipei  CSIE
# 5   s1334987   Emily   168.5    53.6    2  1982/10/13  Kaohsiung  CSIE
# 6   e1384726  Ubuntu   177.0    68.3    1    1981/7/6  Kaohsiung    EE
