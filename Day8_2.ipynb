# %% [markdown]
# <a href="https://colab.research.google.com/github/vedkharat/DataScienceInternship/blob/main/Day8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Programmer: Ved Kharat
#College: Keystone
#Class:TE-A
#Roll No:35

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/movies.csv')
df
# Out:
#                               Movie      Budget  Celebrities             Class
# 0                     The 400 Blows   100000000          2.0  Box Office Burst
# 1                         La Haine    210000000          3.0  Box Office Burst
# 2                     The Godfather   250000000          4.0  Box Office Burst
# 3           The Godfather: Part II    350000000          2.0  Box Office Burst
# 4                    Man Bites Dog    400600000          4.0  Box Office Burst
# 5                      The Departed   500000000          2.0  Box Office Burst
# 6                       Umberto D.    550000000          5.0  Box Office Burst
# 7                        White Heat   610450000          4.0  Box Office Burst
# 8                 Eddie Murphy: Raw   650000000          3.0  Box Office Burst
# 9    All Quiet on the Western Front  1000000000          5.0  Box Office Burst
# 10                        Duck Soup   100000000          5.5  Critical Success
# ...

# %%
sns.jointplot(x='Budget',y='Celebrities',data=df,hue='Class')

# %%
x=df[['Budget','Celebrities']]
y=df['Class']

# %%
x.head()
# Out:
#       Budget  Celebrities
# 0  100000000          2.0
# 1  210000000          3.0
# 2  250000000          4.0
# 3  350000000          2.0
# 4  400600000          4.0

# %%
y.head()
# Out:
# 0    Box Office Burst
# 1    Box Office Burst
# 2    Box Office Burst
# 3    Box Office Burst
# 4    Box Office Burst
# Name: Class, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(random_state=0)

# %%
dt.fit(x,y)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# Predict on new values

# %%
newl=[[5000000,7]]

# %%
dt.predict(newl)
# Out:
# array(['Critical Success'], dtype=object)
